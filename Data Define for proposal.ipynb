# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\malabdul\\Documents\\LearnDoc\\Sadaia\\Data Analysis\\Project\\Real_Estate_Sales_2001-2016.csv\\Real_Estate_Sales_2001-2016.csv")
pd.set_option("display.max_columns", None)
df.head()
# Out:
#   ID  SerialNumber  ListYear            DateRecorded     Town  \
# 0  1         14046      2014  09/29/2015 12:00:00 AM  Andover
# 1  2        900035      2009  07/20/2010 12:00:00 AM  Andover
# 2  3         14011      2014  01/14/2015 12:00:00 AM  Andover
# 3  4         80009      2008  01/21/2009 12:00:00 AM  Andover
# 4  5         15006      2015  11/30/2015 12:00:00 AM  Andover
#
#                        Address AssessedValue SaleAmount  SalesRatio  \
# 0   US ROUTE 6  M 33 B 36 L 22        10,720     75,000    0.142933
# 1              1 DOGWOOD DRIVE        55,600     99,000    0.561616
# 2              1 JUROVATY LANE       153,100    190,000    0.805789
# 3                  1 ROSE LANE       116,600    138,900    0.839453
# 4                  1 ROSE LANE       102,900     50,000    2.058000
#
#   PropertyType ResidentialType        NonUseCode  \
# 0  Vacant Land             NaN               NaN
# 1  Vacant Land             NaN               NaN
# ...

# %%
df.shape
# Out:
# (815905, 13)

# %%
df.sort_values(['Town', 'PropertyType'], ascending=[True, True])
# Out:
#              ID  SerialNumber  ListYear            DateRecorded       Town  \
# 495         496        120042      2012  08/14/2013 12:00:00 AM    Andover
# 618         619         20006      2002  11/07/2002 12:00:00 AM    Andover
# 619         620         20006      2002  11/07/2002 12:00:00 AM    Andover
# 60           61         50058      2005  03/23/2006 12:00:00 AM    Andover
# 335         369         14013      2014  02/25/2015 12:00:00 AM    Andover
# ...         ...           ...       ...                     ...        ...
# 815617  815,618        120076      2012  04/18/2013 12:00:00 AM  Woodstock
# 815622  815,623        120106      2012  06/05/2013 12:00:00 AM  Woodstock
# 815695  815,696        120110      2012  06/17/2013 12:00:00 AM  Woodstock
# 815743  815,744        120109      2012  06/17/2013 12:00:00 AM  Woodstock
# 815805  815,806        120018      2012  11/15/2012 12:00:00 AM  Woodstock
#
# ...
